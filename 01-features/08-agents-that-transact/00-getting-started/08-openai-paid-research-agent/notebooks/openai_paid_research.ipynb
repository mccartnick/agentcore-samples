# %% [markdown]
# # Budget-Bounded OpenAI Multi-Agent Research
#
# This notebook is a thin walkthrough over the tutorial's Python files. Complete the exercises in [`../BUILD.md`](../BUILD.md) first.
#
# ![Budget-bounded multi-agent paid research architecture](../images/architecture.png)

# %% [markdown]
# ## 1. Install
#
# The notebook and README share one implementation and one architecture image.

# %%
# %pip install -q -r ../requirements.txt

# %% [markdown]
# ## 2. Load the starter

# %%
import sys
from pathlib import Path

tutorial_dir = Path.cwd().parent
if str(tutorial_dir) not in sys.path:
    sys.path.insert(0, str(tutorial_dir))

from openai_paid_research import build_research_team, load_environment
from payment import PaymentConfig, create_payment_session, fetch_x402

load_environment()

# %% [markdown]
# ## 3. Inspect the bound configuration
#
# This displays identifiers only. Wallet-provider credentials are not read by this tutorial.

# %%
config = PaymentConfig.from_env()
{
    "region": config.region,
    "paid_url": config.paid_url,
    "budget": config.budget,
    "expiry_minutes": config.expiry_minutes,
}

# %% [markdown]
# ## 4. Complete and test the exercise
#
# Implement `create_payment_session`, `fetch_x402`, and `build_research_team`. Then run `pytest -q` from the tutorial directory before attempting a live payment.
